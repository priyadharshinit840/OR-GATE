# %%
import numpy as np
import pandas as pd
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# XOR Dataset
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

y = np.array([0, 1, 1, 0])

# Split dataset into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(
    X, y,
    test_size=0.5,
    random_state=42
)

# Hidden neuron configurations
neurons = [2, 4, 8, 16]

results = []

for n in neurons:
    model = MLPClassifier(
        hidden_layer_sizes=(n,),
        activation='logistic',
        solver='lbfgs',
        max_iter=1000,
        random_state=42
    )

    model.fit(X_train, y_train)

    train_pred = model.predict(X_train)
    val_pred = model.predict(X_val)

    train_acc = accuracy_score(y_train, train_pred)
    val_acc = accuracy_score(y_val, val_pred)

    results.append([
        n,
        train_acc,
        val_acc,
        model.loss_
    ])

# Display results
df = pd.DataFrame(
    results,
    columns=[
        "Hidden Neurons",
        "Training Accuracy",
        "Validation Accuracy",
        "Loss"
    ]
)

print(df)
# Out:
#    Hidden Neurons  Training Accuracy  Validation Accuracy      Loss
# 0               2                1.0                  0.0  0.005709
# 1               4                1.0                  0.0  0.004932
# 2               8                1.0                  0.0  0.004555
# 3              16                1.0                  0.0  0.004044
